# %%
import pandas as pd 
import numpy as np
dfp = pd.read_excel("pp_full_data.xlsx")
dfp
# Out:
#        Sr No. Date of\nEncashment               Name of the Political Party  \
# 0           1          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1           2          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2           3          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3           4          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4           5          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# ...       ...                 ...                                       ...
# 20416   20417          2024-01-24                            JANASENA PARTY
# 20417   20418          2024-01-24                            JANASENA PARTY
# 20418   20419          2024-01-24                            JANASENA PARTY
# 20419   20420          2024-01-24                            JANASENA PARTY
# 20420   20421          2024-01-24                            JANASENA PARTY
#
# ...

# %%
#renaming columns 
dfp.rename({"Date of\nEncashment":"Date of Encashment","Account no. of\nPolitical Party": "Account no. of Political Party",
           "Bond\nNumber": "Bond Number", "Pay Branch\nCode": "Pay Branch Code"}, axis = 1,inplace = True)

# %%
dfp
# Out:
#        Sr No. Date of Encashment               Name of the Political Party  \
# 0           1         2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1           2         2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2           3         2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3           4         2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4           5         2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# ...       ...                ...                                       ...
# 20416   20417         2024-01-24                            JANASENA PARTY
# 20417   20418         2024-01-24                            JANASENA PARTY
# 20418   20419         2024-01-24                            JANASENA PARTY
# 20419   20420         2024-01-24                            JANASENA PARTY
# 20420   20421         2024-01-24                            JANASENA PARTY
#
# ...

# %%
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20421 entries, 0 to 20420
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Sr No.                          20421 non-null  int64
#  1   Date of Encashment              20421 non-null  datetime64[ns]
#  2   Name of the Political Party     20421 non-null  object
#  3   Account no. of Political Party  20421 non-null  object
#  4   Prefix                          20421 non-null  object
#  5   Bond Number                     20421 non-null  int64
#  6   Denominations                   20421 non-null  int64
#  7   Pay Branch Code                 20421 non-null  int64
#  8   Pay Teller                      20421 non-null  int64
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 1.4+ MB

# %%
dfp.loc[dfp["Bond Number"] == 1098]
#we can seet hat bond number are repeating but what makes them unique is their prefix and bond number togather
# which we can use to joi it with dinor list.
# Out:
#        Sr No. Date of Encashment Name of the Political Party  \
# 2641     2642         2019-04-23      BHARATIYA JANATA PARTY
# 4376     4377         2019-10-11      BHARATIYA JANATA PARTY
# 11920   11921         2022-10-20             AAM AADMI PARTY
#
#       Account no. of Political Party Prefix  Bond Number  Denominations  \
# 2641                     *******8244     OL         1098         100000
# 4376                     *******8244     OC         1098       10000000
# 11920                    *******5086     TL         1098        1000000
#
#        Pay Branch Code  Pay Teller
# 2641               691     3300196
# 4376               691     2039265
# 11920              691     5972302

# %%
dfp["Bond Number"].nunique()
# Out:
# 15296

# %%
dfp["pkey"] = dfp["Prefix"] + "-" + dfp["Bond Number"].astype(str)

# %%
dfp
# Out:
#        Sr No. Date of Encashment               Name of the Political Party  \
# 0           1         2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1           2         2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2           3         2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3           4         2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4           5         2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# ...       ...                ...                                       ...
# 20416   20417         2024-01-24                            JANASENA PARTY
# 20417   20418         2024-01-24                            JANASENA PARTY
# 20418   20419         2024-01-24                            JANASENA PARTY
# 20419   20420         2024-01-24                            JANASENA PARTY
# 20420   20421         2024-01-24                            JANASENA PARTY
#
# ...

# %%
dfp.drop(["Prefix","Bond Number"],axis =1, inplace = True)

# %%
dfp["Name of the Political Party"].value_counts().reset_index()
# Out:
#                           Name of the Political Party  count
# 0                              BHARATIYA JANATA PARTY   8633
# 1                        ALL INDIA TRINAMOOL CONGRESS   3305
# 2             PRESIDENT, ALL INDIA CONGRESS COMMITTEE   3146
# 3                              BHARAT RASHTRA SAMITHI   1806
# 4                                     BIJU JANATA DAL    861
# 5                     DRAVIDA MUNNETRA KAZHAGAM (DMK)    648
# 6   YSR CONGRESS PARTY (YUVAJANA SRAMIKA RYTHU CON...    469
# 7                                            SHIVSENA    355
# 8                                  TELUGU DESAM PARTY    279
# 9                                     AAM AADMI PARTY    245
# 10                                RASHTRIYA JANTA DAL    150
# 11     NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH    121
# 12                             JANATA DAL ( SECULAR )     75
# 13                           SIKKIM KRANTIKARI MORCHA     50
# ...

# %%
dfp.to_csv("pp_cleaned",index=False)

# %%
import numpy as np
import pandas as pd

df = pd.read_excel("donor full.xlsx")
df.head(5)
# Out:
#    Sr No.  Reference No (URN) Journal Date Date of\nPurchase Date of Expiry  \
# 0       1        1.201904e+18   2019-04-12        2019-04-12     2019-04-26
# 1       2        1.201904e+18   2019-04-12        2019-04-12     2019-04-26
# 2       3        1.201904e+18   2019-04-12        2019-04-12     2019-04-26
# 3       4        1.201904e+18   2019-04-12        2019-04-12     2019-04-26
# 4       5        1.201904e+18   2019-04-12        2019-04-12     2019-04-26
#
#   Name of the Purchaser Column7 Column8 Column9 Prefix  Bond\nNumber  \
# 0   A B C INDIA LIMITED     NaN     NaN     NaN     TL         11448
# 1   A B C INDIA LIMITED     NaN     NaN     NaN     TL         11447
# 2   A B C INDIA LIMITED     NaN     NaN     NaN     TL         11441
# 3   A B C INDIA LIMITED     NaN     NaN     NaN     OL          1113
# 4   A B C INDIA LIMITED     NaN     NaN     NaN     OL          1118
#
#    Denominations  Issue Branch Code  Issue Teller Status
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18871 entries, 0 to 18870
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sr No.                 18871 non-null  int64
#  1   Reference No (URN)     18871 non-null  float64
#  2   Journal Date           18871 non-null  datetime64[ns]
#  3   Date of
# Purchase       18871 non-null  datetime64[ns]
#  4   Date of Expiry         18871 non-null  datetime64[ns]
#  5   Name of the Purchaser  18871 non-null  object
#  6   Column7                158 non-null    object
#  7   Column8                97 non-null     object
#  8   Column9                39 non-null     object
#  9   Prefix                 18871 non-null  object
#  10  Bond
# Number            18871 non-null  int64
#  11  Denominations          18871 non-null  int64
#  12  Issue Branch Code      18871 non-null  int64
#  13  Issue Teller           18871 non-null  int64
# ...

# %%
x = df.loc[df.Column9.notna()].index

# %%
df.loc[x]
# Out:
#        Sr No.  Reference No (URN) Journal Date Date of\nPurchase  \
# 12330   12331        3.002023e+20   2023-04-06        2023-04-06
# 12331   12332        3.002023e+20   2023-04-06        2023-04-06
# 12332   12333        3.002023e+20   2023-04-06        2023-04-06
# 12333   12334        3.002023e+20   2023-04-06        2023-04-06
# 12334   12335        3.002023e+20   2023-04-06        2023-04-06
# 12335   12336        3.002023e+20   2023-04-06        2023-04-06
# 12336   12337        3.002023e+20   2023-04-06        2023-04-06
# 12337   12338        3.002023e+20   2023-04-06        2023-04-06
# 12338   12339        3.002023e+20   2023-04-06        2023-04-06
# 12339   12340        3.002023e+20   2023-04-06        2023-04-06
# 13438   13439        1.202304e+18   2023-04-12        2023-04-12
# 13439   13440        1.202304e+18   2023-04-12        2023-04-12
# 13440   13441        1.202304e+18   2023-04-12        2023-04-12
# ...

# %%
df[["Column7","Column8","Column9"]]=df[["Column7","Column8","Column9"]].fillna("")

# %%
df.loc[x]
# Out:
#        Sr No.  Reference No (URN) Journal Date Date of\nPurchase  \
# 12330   12331        3.002023e+20   2023-04-06        2023-04-06
# 12331   12332        3.002023e+20   2023-04-06        2023-04-06
# 12332   12333        3.002023e+20   2023-04-06        2023-04-06
# 12333   12334        3.002023e+20   2023-04-06        2023-04-06
# 12334   12335        3.002023e+20   2023-04-06        2023-04-06
# 12335   12336        3.002023e+20   2023-04-06        2023-04-06
# 12336   12337        3.002023e+20   2023-04-06        2023-04-06
# 12337   12338        3.002023e+20   2023-04-06        2023-04-06
# 12338   12339        3.002023e+20   2023-04-06        2023-04-06
# 12339   12340        3.002023e+20   2023-04-06        2023-04-06
# 13438   13439        1.202304e+18   2023-04-12        2023-04-12
# 13439   13440        1.202304e+18   2023-04-12        2023-04-12
# 13440   13441        1.202304e+18   2023-04-12        2023-04-12
# ...

# %%
# joining name in column 7,8,9 and name of the purchaser

# %%
df["Name of the Purchaser"] = df["Name of the Purchaser"] + " " + df["Column7"] + " " + df["Column8"] + " " + df["Column9"]

# %%
df.loc[x]
# Out:
#        Sr No.  Reference No (URN) Journal Date Date of\nPurchase  \
# 12330   12331        3.002023e+20   2023-04-06        2023-04-06
# 12331   12332        3.002023e+20   2023-04-06        2023-04-06
# 12332   12333        3.002023e+20   2023-04-06        2023-04-06
# 12333   12334        3.002023e+20   2023-04-06        2023-04-06
# 12334   12335        3.002023e+20   2023-04-06        2023-04-06
# 12335   12336        3.002023e+20   2023-04-06        2023-04-06
# 12336   12337        3.002023e+20   2023-04-06        2023-04-06
# 12337   12338        3.002023e+20   2023-04-06        2023-04-06
# 12338   12339        3.002023e+20   2023-04-06        2023-04-06
# 12339   12340        3.002023e+20   2023-04-06        2023-04-06
# 13438   13439        1.202304e+18   2023-04-12        2023-04-12
# 13439   13440        1.202304e+18   2023-04-12        2023-04-12
# 13440   13441        1.202304e+18   2023-04-12        2023-04-12
# ...

# %%
df.drop(["Column7","Column8","Column9"],axis = 1, inplace = True)

# %%
df.loc[x]
# Out:
#        Sr No.  Reference No (URN) Journal Date Date of\nPurchase  \
# 12330   12331        3.002023e+20   2023-04-06        2023-04-06
# 12331   12332        3.002023e+20   2023-04-06        2023-04-06
# 12332   12333        3.002023e+20   2023-04-06        2023-04-06
# 12333   12334        3.002023e+20   2023-04-06        2023-04-06
# 12334   12335        3.002023e+20   2023-04-06        2023-04-06
# 12335   12336        3.002023e+20   2023-04-06        2023-04-06
# 12336   12337        3.002023e+20   2023-04-06        2023-04-06
# 12337   12338        3.002023e+20   2023-04-06        2023-04-06
# 12338   12339        3.002023e+20   2023-04-06        2023-04-06
# 12339   12340        3.002023e+20   2023-04-06        2023-04-06
# 13438   13439        1.202304e+18   2023-04-12        2023-04-12
# 13439   13440        1.202304e+18   2023-04-12        2023-04-12
# 13440   13441        1.202304e+18   2023-04-12        2023-04-12
# ...

# %%
df.rename({"Date of\nPurchase":"Date of Purchase"},axis=1, inplace = True)

# %%
df.loc[df["Bond\nNumber"]==1098]
# Out:
#        Sr No.  Reference No (URN) Journal Date Date of Purchase  \
# 2774     2775        8.132019e+20   2019-10-05       2019-10-05
# 10040   10041        6.282022e+20   2022-10-10       2022-10-10
#
#       Date of Expiry                    Name of the Purchaser Prefix  \
# 2774      2019-10-19  PRESTIGE NOTTING HILL INVESTMENTS           OC
# 10040     2022-10-24                    AVON CYCLES LTD           TL
#
#        Bond\nNumber  Denominations  Issue Branch Code  Issue Teller Status
# 2774           1098       10000000                813       5144485   Paid
# 10040          1098        1000000                628       5809436   Paid

# %%
df["pkey"] = df["Prefix"] + "-" + df["Bond\nNumber"].astype(str)

# %%
df.drop(["Prefix","Bond\nNumber"],axis =1, inplace = True)

# %%
df["Name of the Purchase"].value_counts().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name of the Purchase'
#
# The above exception was the direct cause of the following exception:
#
# ...
